# %% [markdown]
# ### Sample images from CIFAR100 and CIFAR10 dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.datasets import cifar10

# %%
# if run in colab, upload cifar100_fine_coarse_labels.py
# !rm cifar100_fine_coarse_labels.py

from google.colab import files
uploaded = files.upload()
for file in uploaded:
  print("file name : {} , length: {}".format(file,len(file)))
# Out:
#      <input type="file" id="files-c059ccd0-a92d-400e-ba7f-8e48fa0b8087" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c059ccd0-a92d-400e-ba7f-8e48fa0b8087">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cifar100_fine_coarse_labels.py to cifar100_fine_coarse_labels.py
# file name : cifar100_fine_coarse_labels.py , length: 30

# %%
import importlib 
from  cifar100_fine_coarse_labels import fine_labels, mapping_coarse_fine, Fine100, Coarse100

# %%
def load_data(num_classes):

    if cifar_dataset == 100:
        (x_train, y_train), (x_test, y_test) = cifar100.load_data()
    else :
        (x_train, y_train), (x_test, y_test) = cifar10.load_data()
        
    
    #print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
    #print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
    return (x_train, y_train), (x_test, y_test)

# %% [markdown]
# ### CIFAR100 dataset

# %%
num_classes = 100
(x_train, y_train), (x_test, y_test) = load_data(num_classes)

fine = Fine100(fine_labels)
coarse = Coarse100(mapping_coarse_fine,fine_labels)
nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(5, 5))
plt.subplots_adjust(hspace=0.4)
n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(x_train[n])
            fine_id = y_train[n][0]
            #coarse_id = coarse.fine_id_to_coarse_label(fine_id)
            #ax[row,col].set_title('{}:\n{}'.format(coarse.fine_id_to_coarse_label(fine_id), fine.id_to_label(y_train[n][0])))
            ax[row,col].set_title(fine.id_to_label(y_train[n][0]))
            n += 1
plt.show()

# %% [markdown]
# ### CIFAR10 dataset

# %%
cifar_dataset = 10
(x_train, y_train), (x_test, y_test) = read_data(cifar_dataset)

cifar_classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

nrows = 3
ncols = 3
fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True,figsize=(5, 5))
plt.subplots_adjust(hspace=0.4)
n = 0
for row in range(nrows):
    for col in range(ncols):
            ax[row,col].imshow(x_train[n])
            class_id = y_train[n][0]
            ax[row,col].set_title(cifar_classes[class_id])
            n += 1
plt.show()
